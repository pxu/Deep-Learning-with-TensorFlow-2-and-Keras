# %% [markdown]
# <a href="https://colab.research.google.com/github/pxu/Deep-Learning-with-TensorFlow-2-and-Keras/blob/master/alice_text_generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import re
import shutil
import tensorflow as tf

DATA_DIR = "./data"
CHECKPOINT_DIR = os.path.join(DATA_DIR, "checkpoints")
LOG_DIR = os.path.join(DATA_DIR, "logs")


def clean_logs():
    shutil.rmtree(CHECKPOINT_DIR, ignore_errors=True)
    shutil.rmtree(LOG_DIR, ignore_errors=True)


def download_and_read(urls):
    texts = []
    for i, url in enumerate(urls):
        p = tf.keras.utils.get_file("ex1-{:d}.txt".format(i), url,
            cache_dir=".")
        text = open(p, mode="r", encoding="utf-8").read()
        # remove byte order mark
        text = text.replace("\ufeff", "")
        # remove newlines
        text = text.replace('\n', ' ')
        text = re.sub(r'\s+', " ", text)
        # add it to the list
        texts.extend(text)
    return texts


def split_train_labels(sequence):
    input_seq = sequence[0:-1]
    output_seq = sequence[1:]
    return input_seq, output_seq


class CharGenModel(tf.keras.Model):

    def __init__(self, vocab_size, num_timesteps,
            embedding_dim, **kwargs):
        super(CharGenModel, self).__init__(**kwargs)
        self.embedding_layer = tf.keras.layers.Embedding(
            vocab_size,
            embedding_dim
        )
        self.rnn_layer = tf.keras.layers.GRU(
            num_timesteps,
            recurrent_initializer="glorot_uniform",
            recurrent_activation="sigmoid",
            stateful=True,
            return_sequences=True
        )
        self.dense_layer = tf.keras.layers.Dense(vocab_size)

    def call(self, x):
        x = self.embedding_layer(x)
        x = self.rnn_layer(x)
        x = self.dense_layer(x)
        return x

    # ADDED THIS METHOD TO FIX THE ERROR
    def reset_states(self):
        self.rnn_layer.reset_states()


def loss(labels, predictions):
    return tf.losses.sparse_categorical_crossentropy(
        labels,
        predictions,
        from_logits=True
    )


def generate_text(model, prefix_string, char2idx, idx2char,
        num_chars_to_generate=1000, temperature=1.0):
    input = [char2idx[s] for s in prefix_string]
    input = tf.expand_dims(input, 0)
    text_generated = []
    model.reset_states()
    for i in range(num_chars_to_generate):
        preds = model(input)
        preds = tf.squeeze(preds, 0) / temperature
        # predict char returned by model
        pred_id = tf.random.categorical(preds, num_samples=1)[-1, 0].numpy()
        text_generated.append(idx2char[pred_id])
        # pass the prediction as the next input to the model
        input = tf.expand_dims([pred_id], 0)

    return prefix_string + "".join(text_generated)


# download and read into local data structure (list of chars)
texts = download_and_read([
    "http://www.gutenberg.org/cache/epub/28885/pg28885.txt",
    "https://www.gutenberg.org/files/12/12-0.txt"
])
clean_logs()

# create the vocabulary
vocab = sorted(set(texts))
print("vocab size: {:d}".format(len(vocab)))

# create mapping from vocab chars to ints
char2idx = {c:i for i, c in enumerate(vocab)}
idx2char = {i:c for c, i in char2idx.items()}

# numericize the texts
texts_as_ints = np.array([char2idx[c] for c in texts])
data = tf.data.Dataset.from_tensor_slices(texts_as_ints)
# Out:
# vocab size: 94

# %% [markdown]
# number of characters to show before asking for prediction
# sequences: [None, 100]

# %%
seq_length = 100
sequences = data.batch(seq_length + 1, drop_remainder=True)
sequences = sequences.map(split_train_labels)

# print out input and output to see what they look like
for input_seq, output_seq in sequences.take(1):
    print("input:[{:s}]".format(
        "".join([idx2char[i] for i in input_seq.numpy()])))
    print("output:[{:s}]".format(
        "".join([idx2char[i] for i in output_seq.numpy()])))
# Out:
# input:[The Project Gutenberg eBook of Alice's Adventures in Wonderland This eBook is for the use of anyone ]
# output:[he Project Gutenberg eBook of Alice's Adventures in Wonderland This eBook is for the use of anyone a]

# %% [markdown]
# set up for training
# batches: [None, 64, 100]

# %%
batch_size = 64
steps_per_epoch = len(texts) // seq_length // batch_size
dataset = sequences.shuffle(10000).batch(batch_size, drop_remainder=True)
print(dataset)

# define network
vocab_size = len(vocab)
embedding_dim = 256

model = CharGenModel(vocab_size, seq_length, embedding_dim)
model.build(input_shape=(batch_size, seq_length))
model.summary()

# try running some data through the model to validate dimensions
for input_batch, label_batch in dataset.take(1):
    pred_batch = model(input_batch)

print(pred_batch.shape)
assert(pred_batch.shape[0] == batch_size)
assert(pred_batch.shape[1] == seq_length)
assert(pred_batch.shape[2] == vocab_size)

model.compile(optimizer=tf.optimizers.Adam(), loss=loss)
# Out:
# <_BatchDataset element_spec=(TensorSpec(shape=(64, 100), dtype=tf.int64, name=None), TensorSpec(shape=(64, 100), dtype=tf.int64, name=None))>
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/layer.py:424: UserWarning: `build()` was called on layer 'char_gen_model_3', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# Model: "char_gen_model_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_3 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_3 (GRU)                     │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# (64, 100, 94)

# %% [markdown]
# we will train our model for 50 epochs, and after every 10 epochs
# we want to see how well it will generate text

# %%
num_epochs = 50
for i in range(num_epochs // 10):
    model.fit(
        dataset.repeat(),
        epochs=10,
        steps_per_epoch=steps_per_epoch
    )
    checkpoint_file = os.path.join(CHECKPOINT_DIR, "model_epoch_{:d}.weights.h5".format((i + 1) * 10))
    model.save_weights(checkpoint_file)

    # 1. Create the generative model instance
    gen_model = CharGenModel(vocab_size, seq_length, embedding_dim)

    # 2. FIXED: Pass dummy data (shape: batch_size=1, sequence_length=1) to safely build the layers
    gen_model(tf.zeros((1, 1)))

    # 3. Now the weights can load perfectly!
    gen_model.load_weights(checkpoint_file)

    print("\n" + "=" * 40)
    print("after epoch: {:d}".format((i + 1) * 10))
    print(generate_text(gen_model, "Alice ", char2idx, idx2char))
    print("=" * 40 + "\n")
# Out:
# Epoch 1/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 7s 137ms/step - loss: 1.4745
# Epoch 2/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 154ms/step - loss: 1.4693
# Epoch 3/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 157ms/step - loss: 1.4623
# Epoch 4/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 7s 143ms/step - loss: 1.4568
# Epoch 5/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 158ms/step - loss: 1.4517
# Epoch 6/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 158ms/step - loss: 1.4453
# Epoch 7/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 7s 143ms/step - loss: 1.4407
# Epoch 8/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 158ms/step - loss: 1.4364
# Epoch 9/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 157ms/step - loss: 1.4320
# Epoch 10/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 7s 144ms/step - loss: 1.4265
#
# ========================================
# after epoch: 10
# Alice was added till him—and seck dereaution this, and looked! They have a pear that do contains comffollowed it," said the Queen (What’says getting hopes, when ther, they---y coot? Come a couldn't came---M'—"I shake that ever was beinution from numbsion again I cappening myself. Exmed!" "You’ll be hur getted Pride Q. **** SRAPTBEB EBFUERG LINT I tI like like bird, loied, “Mar half ever’ll paar I canever have a ping pity up, and down any minely along up times which a _llart of bild not offendiousry on congines of sigh! How ploath a moush the eppeaded the King was were hirsed to them holwand her sise, I sheir quite to post of the septer of little jomournely, the whilat down. "It's very place, 8ry it head all hal! Said Alice was cleared, and him at firh all the good cat lesten your felcomfous with I'm all his thou home consectening. The hally? I seem him, which of a spee laars and ture in a got as walks haisecked a converys of at wide. "Why, that I can’t dispissmet,” said the sing thung kishat
# ========================================
#
# Epoch 1/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 145ms/step - loss: 1.4237
# Epoch 2/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 154ms/step - loss: 1.4191
# Epoch 3/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 160ms/step - loss: 1.4158
# Epoch 4/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 151ms/step - loss: 1.4122
# Epoch 5/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 151ms/step - loss: 1.4075
# Epoch 6/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 160ms/step - loss: 1.4040
# Epoch 7/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 161ms/step - loss: 1.4013
# Epoch 8/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 7s 144ms/step - loss: 1.3989
# Epoch 9/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 161ms/step - loss: 1.3937
# Epoch 10/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 159ms/step - loss: 1.3913
#
# ========================================
# after epoch: 20
# Alice took the disth of close. “And that stramine way is,” sale letsation timbly, as greep Alicure quietly upon ablice," thout of conteral offendly, my knowle hand with to would glisputting Without Gutenberg UGn’t me crom of copyrod it at middle other Frond. It make a because?” “If I can't comfity for should, to prytying, was nce way of mone-hors to demme to come and repeat, and then in liad--by much of instanding all, Lily, "I directly ought! Try was beginning, And over your are middle remark away what you's agread. "That've go how back in youbther, joves it in teaty of the lartly from, I pause.” “I say least finger,” the Parch with the first! Ding-nothing your intand into the way to the wonderarns. Somord beincing preceld bushed other an eagerly this thout or gunes, and shall So-Moodhate’ formay _plase_," was so hands to beall if Alice quite rament her rattles about began at it have really added all the Kiversaid it into it?’ Dodary um other door," said it oughat is it open it withrow of t
# ========================================
#
# Epoch 1/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 142ms/step - loss: 1.3881
# Epoch 2/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 155ms/step - loss: 1.3861
# Epoch 3/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 160ms/step - loss: 1.3827
# Epoch 4/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 9s 169ms/step - loss: 1.3794
# Epoch 5/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 151ms/step - loss: 1.3771
# Epoch 6/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 153ms/step - loss: 1.3751
# Epoch 7/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 160ms/step - loss: 1.3723
# Epoch 8/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 159ms/step - loss: 1.3710
# Epoch 9/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 159ms/step - loss: 1.3673
# Epoch 10/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 155ms/step - loss: 1.3656
#
# ========================================
# after epoch: 30
# Alice dog ordy, sent, and 'wook. CHaAze was the Project Gntended to is breauting out: “where isne of it," said the Gryphon could havened Aitten over what was a deep garden in she did not havely down and goartt of the quenty agains round it way that this thing wone they dessiges, when they wale off. "Can _what _It_ ners, and no harts logses." "In'te seem,” at They, Kittered of the flocking quite in a solven montaitly as what in the orselp singing it.) “But what up and dike—the thoughts, a like a Cat lisine feft the jury of it sevoit! "They coming, I only loud, who was it undersop any what the remend—and his eyes slilice, _he_ came Grypake on the Project Gutenberg and the baltaring Alice did half archesion whispes. "I do bely-talk, and Mess and way, by their bark," said the Marunces of the bebous and or the made to here without one Alice asked in bird again: "Who And loud of this moment, I’ll cot she messing some other. The March Hare. You see heard them, in a little, fook she turn up a fillis
# ========================================
#
# Epoch 1/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 152ms/step - loss: 1.3648
# Epoch 2/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 7s 141ms/step - loss: 1.3610
# Epoch 3/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 162ms/step - loss: 1.3596
# Epoch 4/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 159ms/step - loss: 1.3568
# Epoch 5/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 7s 143ms/step - loss: 1.3562
# Epoch 6/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 164ms/step - loss: 1.3529
# Epoch 7/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 161ms/step - loss: 1.3524
# Epoch 8/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 166ms/step - loss: 1.3496
# Epoch 9/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 7s 147ms/step - loss: 1.3478
# Epoch 10/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 158ms/step - loss: 1.3455
#
# ========================================
# after epoch: 40
# Alice celt, after was other a dear, and said, becad of Re_ didn’t down; a bats. He copys mectrose--He didn't arlose! Howen wish to time into--call the Red Wall, she skight." "Onlent door—the mulles said to her in her leep and there of the shoor amongle that the time founds the congity mam?" The frowled out shout they like have reply. The Duchess for it, In much faghtled are mumsenger noticed to just shild about she can. “This eye a chose. “Oh, you?" the Duchess, and looked that began are back very wonder-getts on Alice thing very mushraging on the door sideened far up to the table, cook came face frombody countal there waited the gridn his way of the happen that she have the little heft out of likely, as she helping. "What I couldn’t in the grounder, I’ll easing first to be Carrious_ got never hard.” So Alice said, to res voice, "'Fur Cranag!” the Queen said his bring when she gamod as quite after stamping hard she came head dreave Firen darke," it flenching Alice's a’ll turning. Alice said
# ========================================
#
# Epoch 1/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 9s 167ms/step - loss: 1.3450
# Epoch 2/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 9s 162ms/step - loss: 1.3426
# Epoch 3/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 148ms/step - loss: 1.3413
# Epoch 4/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 161ms/step - loss: 1.3396
# Epoch 5/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 160ms/step - loss: 1.3373
# Epoch 6/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 161ms/step - loss: 1.3364
# Epoch 7/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 155ms/step - loss: 1.3347
# Epoch 8/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 158ms/step - loss: 1.3325
# Epoch 9/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 162ms/step - loss: 1.3304
# Epoch 10/10
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 148ms/step - loss: 1.3286
#
# ========================================
# after epoch: 50
# Alice was gue, is, you must leand about a little guest time them scatsad-hardly re one thing such a hight herself. "om such a great shoulders—_muck!’ I never lead mannation.” “I wanies from like a fly, which fet the White Rabbit facling, “the words begas—mutton and round? ‘_I _then _she said sawhentles I lousing all while the Notenerw, and yes they addail sort thought "The Mock Hatton the never fell—and, if you, won't get to suddenly with the Door; and Betim something riddles began afterbeing some tone and dreadfulons to had when get out with hens of the White Queen said. “To the tall "What sque’s in the song, Beaut! What I curise," said the end of the ground at the refund like with otherse?” Alice would very uncoming as well of mine in contened Alice, "and you curious chose the bran thoughtten” splasly know would gave's alkinger the sunnts over us again (doo you meid 290 But it wouldn’t do his castle—and and a shafely asioly said Diver reach offended with a tone of Meauth rather," said Alic
# ========================================
